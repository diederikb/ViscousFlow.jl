# %% [markdown]
# # Vortex sheet behind elliptically loaded wing

# %%
using Pkg
Pkg.activate("/Users/beckers/Google Drive/Academic/UCLA/CodingInProgress/ViscousFlow.jl");
using ViscousFlow
using Plots
using LinearAlgebra
using DifferentialEquations
using BenchmarkTools
# pyplot()
clibrary(:colorbrewer)
default(grid = false)

# %%
mutable struct Vortex
    x::Real
    y::Real
    Γ::Real
end

# %%
function advect!(p::Vortex, u::Real, v::Real , Δt::Float64) where T
    p.x += u*Δt
    p.y += v*Δt
end
# Out:
# advect! (generic function with 1 method)

# %% [markdown]
# ### Eulerian grid

# %%
nx = 128; ny = 128;
Lx = 4.0;
dx = Lx/(nx-2);
display(dx)
s = Nodes(Dual,(nx,ny));
q = Edges(Primal,(nx,ny));
ψ = Nodes(Dual,w);
L = plan_laplacian(size(w),with_inverse=true)
L⁻¹(w::T) where {T} = L\w;
# Out:
# 0.031746031746031744

# %% [markdown]
# ### Problem parameters

# %%
nvortices = 4
xmin_sheet = 1.0
xmax_sheet = 3.0
y_sheet = 2.0
Γ(x) = 1.0
tloc = 0.0
# Out:
# 0.0

# %% [markdown]
# ### Vortex sheet

# %%
vortices = Array{Vortex,1}()
x_sheet = range(xmin_sheet, xmax_sheet, length=nvortices)

for i in 1:nvortices
    vortex = Vortex(x_sheet[i],y_sheet,Γ(x_sheet[i]))
    push!(vortices,vortex)
end

# %%
vortices
# Out:
# 4-element Array{Vortex,1}:
#  Vortex(1.0, 2.0, 1.0)
#  Vortex(1.6666666666666667, 2.0, 1.0)
#  Vortex(2.3333333333333335, 2.0, 1.0)
#  Vortex(3.0, 2.0, 1.0)

# %%
function rhs(vortices_loc::VectorData,params::Tuple{Nodes,Edges,ScalarData},t)
    
    
    # Regularize vorticity to grid
    Hw = Regularize(vortices_loc,dx;ddftype=Fields.M4prime,issymmetric=true)
    Hw(s,vortices_Γ)
    
    # Solve for streamfunction
    s .= -(L\(s)); 
    
    # Calculate velocity field
    q .= curl(s)/(dx);
    
    
    vel = VectorData(vortices_Γ)
    
    # Interpolate to nodes before interpolating to vortex point
    Fields.interpolate!((s),q.u);
    Hw(vel.u,s)
    Fields.interpolate!((s),q.v);
    Hw(vel.v,s)
    
    return vel
    
end
# Out:
# rhs (generic function with 2 methods)

# %% [markdown]
# ### Time marching

# %%
tf = 4.93
tspan = (0.0,tf);#0.25
vortices_loc = VectorData([vortex.x for vortex in vortices],[vortex.y for vortex in vortices])
vortices_Γ = ScalarData([vortex.Γ for vortex in vortices])
# u0 = [vortices_loc.u vortices_loc.v]
prob = ODEProblem(rhs,vortices_loc,tspan,(s,q,vortices_Γ))
# Out:
# ODEProblem with uType VectorData{4} and tType Float64. In-place: false
# timespan: (0.0, 4.93)
# u0: [1.0, 1.66667, 2.33333, 3.0, 2.0, 2.0, 2.0, 2.0]

# %%
sol = solve(prob,dt=0.1,RK4(),dense=false)
# Out:
# retcode: Success
# Interpolation: 1st order linear
# t: 16-element Array{Float64,1}:
#  0.0
#  0.1
#  0.23670270325434434
#  0.4378584195905177
#  0.7492966769796845
#  1.1014538829101512
#  1.5109478365747144
#  1.9239545498375437
#  2.351005820437125
#  2.7579427340853813
#  3.1513157497951885
#  3.5262054983458118
#  3.8870164113954635
#  4.260404506002491
#  4.621087480278431
#  4.93
# u: 16-element Array{VectorData{4},1}:
#  [1.0, 1.66667, 2.33333, 3.0, 2.0, 2.0, 2.0, 2.0]
#  [1.00099, 1.66677, 2.33323, 2.99901, 1.95621, 1.98806, 2.01194, 2.04379]
#  [1.00557, 1.66725, 2.33275, 2.99443, 1.89651, 1.97179, 2.02821, 2.10349]
#  [1.01905, 1.66861, 2.33139, 2.98095, 1.80939, 1.94802, 2.05198, 2.19061]
#  [1.05567, 1.6718, 2.3282, 2.94433, 1.67768, 1.91198, 2.08802, 2.32232]
#  [1.11988, 1.6756, 2.3244, 2.88012, 1.53628, 1.87263, 2.12737, 2.46372]
#  [1.22441, 1.67686, 2.32314, 2.77559, 1.38707, 1.82831, 2.17169, 2.61293]
#  [1.3616, 1.66939, 2.33061, 2.6384, 1.2605, 1.78232, 2.21768, 2.7395]
#  [1.53495, 1.64699, 2.35301, 2.46505, 1.16641, 1.72553, 2.27447, 2.83359]
#  [1.72279, 1.61279, 2.38721, 2.27721, 1.1276, 1.64897, 2.35103, 2.8724]
#  [1.90595, 1.58411, 2.41589, 2.09405, 1.15317, 1.53943, 2.46057, 2.84683]
#  [2.05143, 1.59081, 2.40919, 1.94857, 1.23669, 1.40138, 2.59862, 2.76331]
#  [2.14024, 1.65383, 2.34617, 1.85976, 1.34971, 1.25926, 2.74074, 2.65029]
#  [2.17997, 1.77779, 2.22221, 1.82003, 1.46443, 1.13832, 2.86168, 2.53557]
#  [2.18972, 1.93268, 2.06732, 1.81028, 1.55265, 1.067, 2.933, 2.44735]
#  [2.19176, 2.07575, 1.92425, 1.80824, 1.60908, 1.04302, 2.95698, 2.39092]

# %%
p = plot(sol)
# savefig("vortex_pair_rotating_goza_coordinates.pdf")

# %% [markdown]
# ### Plot results

# %%
matched_tuples = [(i,i+nvortices) for i in 1:nvortices]
# Out:
# 4-element Array{Tuple{Int64,Int64},1}:
#  (1, 5)
#  (2, 6)
#  (3, 7)
#  (4, 8)

# %%
xg,yg = coordinates(ψ,dx=dx)
coord = [(x,y) for x in xg, y in yg]

paired_indices = nvortices

plots_array = Array{Plots.Plot,1}()

for i in 1:nvortices
    p = scatter(first.(coord)[:],last.(coord)[:],ratio=:equal,markersize=1)
    plot!(sol,vars=(i,i+nvortices),lw=2)
    scatter!([sol[end][i]],[sol[end][i+nvortices]])
    xlims!(minimum(sol[i,:])-1*dx,maximum(sol[i,:])+1*dx)
    ylims!(minimum(sol[i+nvortices,:])-1*dx,maximum(sol[i+nvortices,:])+1*dx)
    push!(plots_array,p)
end

p3 = plot(plots_array...,layout=(1,nvortices),size=[800,400])
# savefig("vortex_pair_rotating_goza_trajectories.pdf")

matched_tuples = [(i,i+nvortices) for i in 1:nvortices]
p4 = plot(sol,vars=matched_tuples,lw=2,color=:black)
# scatter!([sol[end][1],sol[end][2]],[sol[end][3],sol[end][4]])
plot!(xg,yg,ψ,levels=20);
plot!(xlims=(0,Lx),ylims=(0,Lx))
# savefig("vortex_pair_rotating_goza.pdf")

display(p3)

display(p4)

# %% [markdown]
# ### Analytical results

# %%
d = sqrt((vortices[1].x-vortices[2].x)^2 + (vortices[1].y-vortices[2].y)^2)
# Out:
# 0.5

# %% [markdown]
# #### Opposite circulation

# %%
U = vortices[1].Γ/(4π*d)
println("Analytical self-induced velocity = $U")
println("Analytical distance traveled = $(U*tf)")
println("Numerical distance traveled = $(sol[1][1]-sol[end][1])")
# Out:
# Analytical self-induced velocity = 0.15915494309189535
# Analytical distance traveled = 0.784633869443044
# Numerical distance traveled = 0.002885700269819935

# %% [markdown]
# #### Equal circulation

# %%
T = 2π^2*d^2/vortices[1].Γ
println("Analytical period = $T")
# Out:
# Analytical period = 4.934802200544679

# %%
0.050550532375431945/1.5915494309189535
# Out:
# 0.031761836229142

# %%
dx*2
# Out:
# 0.031746031746031744
