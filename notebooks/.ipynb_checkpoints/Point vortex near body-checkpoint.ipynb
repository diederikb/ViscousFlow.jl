# %% [markdown]
# # Point vortex in potential flow

# %%
using Pkg
Pkg.activate("/Users/beckers/Google Drive/Academic/UCLA/CodingInProgress/ViscousFlow.jl");
using ViscousFlow
using Plots
using LinearAlgebra
pyplot()
clibrary(:colorbrewer)
default(grid = false)

# %% [markdown]
# ### Interpolation kernel

# %%
function W(u,h)
    v = abs(u)/h
    if 0 ≤ v ≤ 1
        return 1-5*v^2/2+3*v^3/2
    elseif 1 ≤ v ≤ 2
        return 0.5*(2-v)^2*(1-v)
    else
        return 0
    end
end

function dW(u,h)
    v = u/h
    if 0 ≤ abs(v) ≤ 1
        return sign(u)*(-5*abs(v)+9*abs(v)^2/2)
    elseif 1 ≤ abs(v) ≤ 2
        return sign(u)*(-1.5*abs(v)^2+5*abs(v)-4)
    else
        return 0
    end
end
# Out:
# dW (generic function with 1 method)

# %%
u = -3:0.1:3
plot(u,M3.(u,1))
plot!(u,dM3.(u,1))
# Out:
# UndefVarError: M3 not defined
#
# Stacktrace:
#  [1] top-level scope at In[71]:2

# %%
u = -3:0.1:3
plot(u,W.(u,1))
plot!(u,dW.(u,1))

# %%
ddf = DDF(ddftype=Fields.M4prime,dx=1)
# Out:
# Discrete delta function operator of type ViscousFlow.Fields.M4prime, with spacing 1.0

# %%
u = -3:0.1:3
plot(u,ddf.(u))

# %% [markdown]
# ### Eulerian grid

# %% [markdown]
# ### Regularization/Interpolation

# %%
# Regularize from Lagrangian point
Hw = Regularize(Xᵥ,dx;ddftype=Fields.M4prime,issymmetric=true)
# Interpolate from Eulerian grid
# Out:
# UndefVarError: Xᵥ not defined
#
# Stacktrace:
#  [1] top-level scope at In[75]:1

# %%
nx = 128; ny = 128;
Lx = 2.0;
dx = Lx/(nx-2);
w = Nodes(Dual,(nx,ny));
ψ = Nodes(Dual,w);
L = plan_laplacian(size(w),with_inverse=true)
# Out:
# Discrete Laplacian (and inverse) on a (nx = 128, ny = 128) grid with spacing 1.0

# %% [markdown]
# ### Lagrangian points

# %%
n = 196

R = 0.5
body = Ellipse(R,R,n)

# Find the minimum arc length
ds = minimum(Bodies.dlength(body))

# Move the circle
xc = 1.0; yc = 1.0
T = RigidTransform((xc,yc),0.0)
T(body)

X = VectorData(body.x,body.y)
f = ScalarData(X);
ψb = ScalarData(X);

# Vortex point
Xv = VectorData([1.0],[1.75])
Γv = ScalarData([1.0]);

# %% [markdown]
# ### Problem parameters

# %%
# The desired streamfunction on the circle surface
ψb .= 1

# The desired circulation about the circle
Γ0 = -1;

# %% [markdown]
# ### Vorticity

# %%
Hv = Regularize(Xv,dx;ddftype=Fields.M4prime,issymmetric=true)
Hv(w,Γv);
# show(IOContext(stdout, :compact => true,:limit => false), "text/plain", w)

# %% [markdown]
# ### Saddle point system

# %%
E = Regularize(X,dx;issymmetric=true)
Hmat,Emat = RegularizationMatrix(E,f,w);

# %%
L⁻¹(w::T) where {T} = L\w
PS = SaddleSystem((w,f),(L⁻¹,Hmat,Emat),issymmetric=true,isposdef=true)
# Out:
# Saddle system with 196 constraints and
#    State of type Nodes{Dual,128,128}
#    Force of type ScalarData{196}

# %%
oB = zeros(size(f))
oB .= 1;

# %%
S = Matrix(PS.S);

# %%
S₀ = transpose(oB)*(S\oB)
T = S - oB*transpose(oB)/S₀;

# %% [markdown]
# TODO: write out formulas

# %%
# Note that the first term is actually zero when `ψb` is uniform:
f .= S\(T*(S\(Emat*(L\w).+ψb)) .+ Γ0*oB/S₀);

# %%
ψ₀ = -1/S₀*(Γ0 - transpose(oB)*(S\(Emat*(L\w).+ψb)))
# Out:
# 1.0629200328690904

# %%
ψ .= -(L\(Hmat*f))-(L\(w)) .+ ψ₀;

# %%
xg,yg = coordinates(ψ,dx=dx)
plot(xg,yg,ψ,levels=70)
plot!(body,fillcolor=:black,fillrange=0,fillalpha=0.25,linecolor=:black)

# %%
vel = curl(ψ)
# Out:
# Edges{Primal,128,128} data
# u (in grid orientation)
# 127×128 Array{Float64,2}:
#   0.000562779   0.000570694   0.000578545  …   0.000570694   0.000562779
#   0.000584616   0.000593536   0.000602446      0.000593536   0.000584616
#   0.000606444   0.00061639    0.000626381      0.00061639    0.000606444
#   0.000628209   0.000639199   0.000650292      0.000639199   0.000628209
#   0.000649856   0.000661904   0.000674116      0.000661904   0.000649856
#   0.000671329   0.000684445   0.000697789  …   0.000684445   0.000671329
#   0.000692568   0.000706759   0.000721243      0.000706759   0.000692568
#   0.000713512   0.000728781   0.000744409      0.000728781   0.000713512
#   0.0007341     0.000750445   0.000767216      0.000750445   0.0007341
#   0.000754268   0.000771683   0.000789592      0.000771683   0.000754268
#   0.000773952   0.000792425   0.000811462  …   0.000792425   0.000773952
#   0.000793088   0.000812604   0.000832753      0.000812604   0.000793088
#   0.000811612   0.000832149   0.000853389      0.000832149   0.000811612
#   ⋮                                        ⋱
#  -0.000102231  -0.000108613  -0.000115156  …  -0.000108613  -0.000102231
#  -0.00010452   -0.000110798  -0.00011723      -0.000110798  -0.00010452
#  -0.000106655  -0.000112829  -0.000119149     -0.000112829  -0.000106655
#  -0.000108644  -0.000114712  -0.000120921     -0.000114712  -0.000108644
#  -0.000110492  -0.000116455  -0.000122553     -0.000116455  -0.000110492
#  -0.000112205  -0.000118064  -0.000124051  …  -0.000118064  -0.000112205
#  -0.000113791  -0.000119546  -0.000125423     -0.000119546  -0.000113791
#  -0.000115254  -0.000120905  -0.000126672     -0.000120905  -0.000115254
#  -0.0001166    -0.000122148  -0.000127807     -0.000122148  -0.0001166
#  -0.000117834  -0.00012328   -0.000128831     -0.00012328   -0.000117834
